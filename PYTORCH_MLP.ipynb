# %% [markdown]
# <a href="https://colab.research.google.com/github/ankan-git-coder/Deep-learning-COURSE/blob/main/PYTORCH_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# %%
class SimpleMLP(nn.Module):
  def __init__(self):
      super(SimpleMLP, self).__init__()
      self.hidden = nn.Linear(2,2)
      self.output= nn.Linear(2,1)
      self.sigmoid= nn.Sigmoid()
  def forward(self,x):
      x= self.sigmoid(self.hidden(x))
      x= self.sigmoid(self.output(x))
      return x
# 2. Initialize Model, Loss, and Optimizer
model = SimpleMLP()
criterion = nn.BCELoss() # Binary Cross Entropy for loss
optimizer = torch.optim.SGD(model.parameters(), lr=0.1) # For Weight Updation

inputs=torch.tensor([[1.0,2.0]])
target = torch.tensor([[1.0]])

prediction = model(inputs)
loss= criterion(prediction,target)

optimizer.zero_grad()
loss.backward()
optimizer.step()

print(f"Prediction: {prediction.item():.4f}, Loss: {loss.item():.4f}")
# Out:
# Prediction: 0.4090, Loss: 0.8940
